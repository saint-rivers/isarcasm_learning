# %%
import pandas as pd
import numpy as np
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/dayan/anaconda3/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/dayan/anaconda3/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/dayan/anaconda3/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
# ...

# %%
test = pd.read_csv("../data/huff_onion/headline_test.txt", sep="\t", usecols=[2,3], names=['sarcastic', 'headline'])
train = pd.read_csv("../data/huff_onion/headline_train.txt", sep="\t", usecols=[2,3], names=['sarcastic', 'headline'])
eval = pd.read_csv("../data/huff_onion/headline_val.txt", sep="\t", usecols=[2,3], names=['sarcastic', 'headline'])
clean = pd.read_csv("../data/huff_onion/headlines_clean.txt", sep="\t", usecols=[2,3], names=['sarcastic', 'headline'])
data_clean = pd.read_csv("../data/huff_onion/headlines_data_clean.txt", sep="\t", usecols=[2,3], names=['sarcastic', 'headline'])
sem_eval = pd.read_csv("../data/huff_onion/SemEval.txt", sep="\t", usecols=[2,3], names=['sarcastic', 'headline'])

# %%
print(test.shape[0] + train.shape[0] + eval.shape[0])
print(sem_eval.shape[0])
# Out:
# 26709
# 3827

# %%
train.to_csv("../data/huff_onion/headline_train.csv")
test.to_csv("../data/huff_onion/headline_test.csv")
